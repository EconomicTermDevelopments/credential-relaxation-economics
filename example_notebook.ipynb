# %% [markdown]
# # credential relaxation\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom credential_relaxation import CredentialRelaxationCalculator\n

# %%
df = pd.read_csv("credential_relaxation_dataset.csv")\ndf.head()\n

# %%
calc = CredentialRelaxationCalculator()\nresult = calc.calculate_credential_relaxation(df)\nresult.head()\n

# %%
result["credential_relaxation_index"].describe()\n

# %%
result.groupby("credential_relaxation_band").size()\n

# %%
result["credential_relaxation_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `credential relaxation` index is now ready for stress testing.
